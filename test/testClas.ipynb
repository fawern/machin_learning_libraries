# %%
import sys
sys.path.append("../")

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import classification as cls_

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

df = pd.read_csv("../data/ClasData.csv")

X = df.iloc[:, :-1].values
y = df.iloc[:, -1]

y = y.map({'Onaylandı': 1, 'Reddedildi': 0})

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.2, random_state=42
)

# %%
(
    models_output_list,
    highest_acs_output,
    highest_f1s_output,
    highest_prs_output,
    highest_rcs_output,
    highest_rocs_output,
    
) = cls_.classification_models(X_train, X_test, y_train, y_test)

# %%
value = [
            list(models_output_list.columns), 
            [list(row) for row in models_output_list]
        ]
value
# Out:
#   Cell In[9], line 2
#     list(models_output_list.columns),
#     ^
# SyntaxError: did you forget parentheses around the comprehension target?

# %%
models_output_list
# Out:
#                          Model  Accuracy Score  Precision Score  F1 Score  \
# 0           LogisticRegression        0.666667         0.750000  0.750000
# 1         KNeighborsClassifier        0.500000         1.000000  0.400000
# 2       DecisionTreeClassifier        0.500000         0.600000  0.666667
# 3                          SVC        0.666667         0.666667  0.800000
# 4       RandomForestClassifier        0.333333         0.500000  0.500000
# 5   GradientBoostingClassifier        0.666667         0.750000  0.750000
# 6                XGBClassifier        0.333333         0.500000  0.333333
# 7              XGBRFClassifier        0.333333         0.500000  0.500000
# 8               LGBMClassifier        0.666667         0.666667  0.800000
# 9           CatBoostClassifier        0.500000         0.600000  0.666667
# 10                  GaussianNB        0.500000         0.600000  0.666667
# 11               MLPClassifier        0.666667         0.666667  0.800000
#
#     Recall Score  Roc Auc Score
# 0           0.75          0.625
# 1           0.25          0.625
# 2           0.75          0.375
# 3           1.00          0.500
# 4           0.50          0.250
# 5           0.75          0.625
# 6           0.25          0.375
# 7           0.50          0.250
# 8           1.00          0.500
# 9           0.75          0.375
# 10          0.75          0.375
# 11          1.00          0.500

# %%
print("Classification Models and Evaluation Results:")

print("\nModel with the Highest Accuracy:")
print(highest_acs_output)

print("\nModel with the Highest F1 Score:")
print(highest_f1s_output)

print("\nModel with the Highest Precision:")
print(highest_prs_output)

print("\nModel with the Highest Recall:")
print(highest_rcs_output)

print("\nModel with the Highest ROC-AUC Score:")
print(highest_rocs_output)
# Out:
# Classification Models and Evaluation Results:
#
# Model with the Highest Accuracy:
# Model              LogisticRegression
# Accuracy Score               0.666667
# Precision Score                  0.75
# F1 Score                         0.75
# Recall Score                     0.75
# Roc Auc Score                   0.625
# Name: 0, dtype: object
#
# Model with the Highest F1 Score:
# Model                   SVC
# Accuracy Score     0.666667
# Precision Score    0.666667
# F1 Score                0.8
# Recall Score            1.0
# Roc Auc Score           0.5
# Name: 3, dtype: object
#
# Model with the Highest Precision:
# Model              KNeighborsClassifier
# Accuracy Score                      0.5
# Precision Score                     1.0
# F1 Score                            0.4
# Recall Score                       0.25
# Roc Auc Score                     0.625
# Name: 1, dtype: object
#
# Model with the Highest Recall:
# Model                   SVC
# Accuracy Score     0.666667
# Precision Score    0.666667
# F1 Score                0.8
# Recall Score            1.0
# Roc Auc Score           0.5
# Name: 3, dtype: object
#
# Model with the Highest ROC-AUC Score:
# Model              LogisticRegression
# Accuracy Score               0.666667
# Precision Score                  0.75
# F1 Score                         0.75
# Recall Score                     0.75
# Roc Auc Score                   0.625
# Name: 0, dtype: object

# %%
logreg_model = cls_.Classification(
    model=LogisticRegression(), 
    train_data=X_train, test_data=X_test, 
    train_target=y_train, test_target=y_test
)

svc_model = cls_.Classification(
    model=SVC(),
    train_data=X_train, test_data=X_test,
    train_target=y_train, test_target=y_test
)
rf_model = cls_.Classification(
    model=RandomForestClassifier(),
    train_data=X_train, test_data=X_test,
    train_target=y_train, test_target=y_test
)

print('Logistic Regression accuracy', logreg_model.fit_predict()[1])
print('SVC accuracy', svc_model.fit_predict()[1])
print('Random Forest accuracy', rf_model.fit_predict()[1])
# Out:
# Logistic Regression accuracy 0.6666666666666666
# SVC accuracy 0.6666666666666666
# Random Forest accuracy 0.3333333333333333
